# %%
# 1. Build vectorizers of six datasets.
import os

#--------------------------- Tf-idf weight function --------------------------- 
def build_vectorizer(input_file, output_vectorizer_file):
    from sklearn.feature_extraction.text import TfidfVectorizer
    from sklearn.linear_model import LogisticRegression
    import numpy as np
    import pickle, datetime
    
    # param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000] }
    # param_grid = {'C': [1] }

    # train vectorizer
    vectorizer = TfidfVectorizer(sublinear_tf=True, max_df=0.5, ngram_range=(1, 2), stop_words='english')
    vectorizer.fit(input_file)
    
    with open(output_vectorizer_file, 'wb') as f:
        pickle.dump(vectorizer, f, protocol=pickle.HIGHEST_PROTOCOL)
    
    print("Vectorizer for {} is saved as {}".format(input_file, output_vectorizer_file))
    
    return None
#-----------------------------------------------------------------------------


#---------------------- Build Tf-idf weight maxtrix --------------------------
base_dir  = "./TODO_type_data_directory/"
for root, dirs, files in os.walk(base_dir, topdown=False):
    for name in files:
        if name.endswith('train.txt'):
            print(os.path.join(root, name))
            input_file = os.path.join(root, name)
            labels, texts, label_dict = get_tag_and_training_data(input_file)

            output_file = './model/'+name.replace('.txt', '.vectorizer')
            build_vectorizer(texts, output_file)
#-----------------------------------------------------------------------------

# %%
# Import libraries and define a unitility function for input data.

import numpy as np
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

from sklearn import metrics
from sklearn.metrics import accuracy_score

import pickle
        
RANDOM_SEED = 2212
np.random.seed(RANDOM_SEED)
# Make code reproduce same result.

def get_tag_and_training_data(filename, label_dict=False):
    '''
    takes the input file and returns  tokenized sentences and document tags as separate lists
    How to use:
    Y, X, label_list = get_tag_and_training_data(".../train.txt")
    '''
    original_labels = list()
    initial_label_dict   = {"label2index":{}, "index2label":{}}
    input_label = label_dict
    texts, labels = list(), list()

    with open(filename, encoding='utf8') as f:
        for line in f:
            #Initialize the token list for line
            words  = line.split()
            label = words[0]

            # Original labels
            original_labels.append(label)

            if not input_label:
                label_dict = initial_label_dict
                if label in label_dict["label2index"]: pass
                else :
                    index = len(label_dict["label2index"])
                    label_dict["label2index"][label]= index
                    label_dict["index2label"][index] = label
                    print(index, label, label_dict)

            label_idx = label_dict["label2index"][label]
            labels.append(label_idx)
            sent  = ' '.join(words[1:])
            texts.append(sent)

    return labels, texts, label_dict

# %%
instance_list = [10, 50, 100, 200, 500, 1000, 2000, ""]
# instance_list [""] is using 100% train data


target_list = ['agnews', 'dbpedia', 'amazon_six', 'tripadvisor', 'yahoo_a', 'yelp_f']
for target in target_list:
    
    train_file_path_list = []
    for instance in instance_list:
        train_file_path = "/home/sung_min/experiment_thesis/public_data/Target_"+target+"/"+target+"_train{}.txt".format(instance)
        train_file_path_list.append(train_file_path)

    test_file_path  = "/home/sung_min/experiment_thesis/public_data/Target_"+target+"/"+target+"_test.txt"


    for train_file_path, instance in zip(train_file_path_list, instance_list):

        title = target+'.report'

        y_train, X_train, label_dict = get_tag_and_training_data(train_file_path, label_dict=False)
        y_test,  X_test,  label_dict = get_tag_and_training_data(test_file_path, label_dict=label_dict)




        loaded_vectorizer = True

        if loaded_vectorizer:
            vectorizer = None
            with open('./model/{}_train.vectorizer'.format(target), 'rb') as f:
                vectorizer = pickle.load(f)
        else :
            # train vectorizer
            vectorizer = TfidfVectorizer(sublinear_tf=True, max_df=0.5, ngram_range=(1, 2), stop_words='english')
            vectorizer.fit(X_train)


        X_train = vectorizer.transform(X_train)
        X_test = vectorizer.transform(X_test)
        logistic_clf = LogisticRegression(penalty='l2', random_state=RANDOM_SEED)
        logistic_clf.fit(X_train, y_train)
        y_pred = logistic_clf.predict(X_test)

        # Convert index to label
        y_true = [label_dict["index2label"][idx] for idx in y_test]
        y_pred = [label_dict["index2label"][idx] for idx in y_pred]
        
        # description += "Sample of Y_test : {}, \n Y_pred : {}\n".format(y_true[:10], y_pred[:10])
        description += "\ntarget : {}, instance per class : {}\n\n".format(target, instance if instance != "" else "total")
        
        txt1 = '\n\n\nDescription : '+ str(description) + '\n'
        txt2 = "*"*30 + title +"*"*30 + '\n'
        txt3 = str(metrics.classification_report(y_true, y_pred)) + '\n'
        txt4 = "Accuracy : "+ str(accuracy_score(y_true, y_pred)) + '\n'
# Out:
# 0 SPORTS {'label2index': {'SPORTS': 0}, 'index2label': {0: 'SPORTS'}}
# 1 WORLD {'label2index': {'SPORTS': 0, 'WORLD': 1}, 'index2label': {0: 'SPORTS', 1: 'WORLD'}}
# 2 SCI/TECH {'label2index': {'SCI/TECH': 2, 'SPORTS': 0, 'WORLD': 1}, 'index2label': {0: 'SPORTS', 1: 'WORLD', 2: 'SCI/TECH'}}
# 3 BUSINESS {'label2index': {'SCI/TECH': 2, 'SPORTS': 0, 'WORLD': 1, 'BUSINESS': 3}, 'index2label': {0: 'SPORTS', 1: 'WORLD', 2: 'SCI/TECH', 3: 'BUSINESS'}}
# Save file at  ./report//agnews.report
#
#
#
# Description : Quick accurcy : 48.789474%
# target : agnews, instance per class : 10
#
#
#  ******************************agnews.report******************************
#               precision    recall  f1-score   support
#
#    BUSINESS       0.44      0.56      0.49      1900
#    SCI/TECH       0.51      0.39      0.44      1900
#      SPORTS       0.56      0.46      0.50      1900
#       WORLD       0.48      0.54      0.51      1900
#
# avg / total       0.50      0.49      0.49      7600
#
#  Accuracy : 0.48789473684210527
# ******************************END******************************
#
#
# 0 SPORTS {'label2index': {'SPORTS': 0}, 'index2label': {0: 'SPORTS'}}
# 1 SCI/TECH {'label2index': {'SCI/TECH': 1, 'SPORTS': 0}, 'index2label': {0: 'SPORTS', 1: 'SCI/TECH'}}
# 2 WORLD {'label2index': {'SCI/TECH': 1, 'SPORTS': 0, 'WORLD': 2}, 'index2label': {0: 'SPORTS', 1: 'SCI/TECH', 2: 'WORLD'}}
# 3 BUSINESS {'label2index': {'SCI/TECH': 1, 'SPORTS': 0, 'WORLD': 2, 'BUSINESS': 3}, 'index2label': {0: 'SPORTS', 1: 'SCI/TECH', 2: 'WORLD', 3: 'BUSINESS'}}
# Save file at  ./report//agnews.report
#
#
#
# Description : Quick accurcy : 71.157895%
# target : agnews, instance per class : 50
#
#
#  ******************************agnews.report******************************
#               precision    recall  f1-score   support
#
#    BUSINESS       0.70      0.64      0.67      1900
#    SCI/TECH       0.65      0.68      0.67      1900
#      SPORTS       0.80      0.76      0.78      1900
#       WORLD       0.70      0.76      0.73      1900
#
# avg / total       0.71      0.71      0.71      7600
#
#  Accuracy : 0.7115789473684211
# ******************************END******************************
#
#
# 0 SPORTS {'label2index': {'SPORTS': 0}, 'index2label': {0: 'SPORTS'}}
# 1 SCI/TECH {'label2index': {'SCI/TECH': 1, 'SPORTS': 0}, 'index2label': {0: 'SPORTS', 1: 'SCI/TECH'}}
# 2 BUSINESS {'label2index': {'SCI/TECH': 1, 'SPORTS': 0, 'BUSINESS': 2}, 'index2label': {0: 'SPORTS', 1: 'SCI/TECH', 2: 'BUSINESS'}}
# 3 WORLD {'label2index': {'SCI/TECH': 1, 'SPORTS': 0, 'WORLD': 3, 'BUSINESS': 2}, 'index2label': {0: 'SPORTS', 1: 'SCI/TECH', 2: 'BUSINESS', 3: 'WORLD'}}
# Save file at  ./report//agnews.report
#
#
#
# Description : Quick accurcy : 76.315789%
# target : agnews, instance per class : 100
#
#
#  ******************************agnews.report******************************
#               precision    recall  f1-score   support
#
#    BUSINESS       0.75      0.71      0.73      1900
#    SCI/TECH       0.72      0.73      0.72      1900
#      SPORTS       0.80      0.84      0.82      1900
#       WORLD       0.77      0.77      0.77      1900
#
# avg / total       0.76      0.76      0.76      7600
#
#  Accuracy : 0.7631578947368421
# ******************************END******************************
#
#
# 0 SCI/TECH {'label2index': {'SCI/TECH': 0}, 'index2label': {0: 'SCI/TECH'}}
# 1 WORLD {'label2index': {'SCI/TECH': 0, 'WORLD': 1}, 'index2label': {0: 'SCI/TECH', 1: 'WORLD'}}
# 2 BUSINESS {'label2index': {'SCI/TECH': 0, 'BUSINESS': 2, 'WORLD': 1}, 'index2label': {0: 'SCI/TECH', 1: 'WORLD', 2: 'BUSINESS'}}
# 3 SPORTS {'label2index': {'SCI/TECH': 0, 'BUSINESS': 2, 'WORLD': 1, 'SPORTS': 3}, 'index2label': {0: 'SCI/TECH', 1: 'WORLD', 2: 'BUSINESS', 3: 'SPORTS'}}
# Save file at  ./report//agnews.report
#
#
#
# Description : Quick accurcy : 79.815789%
# target : agnews, instance per class : 200
#
#
#  ******************************agnews.report******************************
#               precision    recall  f1-score   support
#
#    BUSINESS       0.80      0.74      0.77      1900
#    SCI/TECH       0.76      0.74      0.75      1900
#      SPORTS       0.82      0.89      0.85      1900
#       WORLD       0.81      0.82      0.81      1900
#
# avg / total       0.80      0.80      0.80      7600
#
#  Accuracy : 0.7981578947368421
# ******************************END******************************
#
#
# 0 WORLD {'label2index': {'WORLD': 0}, 'index2label': {0: 'WORLD'}}
# 1 BUSINESS {'label2index': {'BUSINESS': 1, 'WORLD': 0}, 'index2label': {0: 'WORLD', 1: 'BUSINESS'}}
# 2 SCI/TECH {'label2index': {'SCI/TECH': 2, 'BUSINESS': 1, 'WORLD': 0}, 'index2label': {0: 'WORLD', 1: 'BUSINESS', 2: 'SCI/TECH'}}
# 3 SPORTS {'label2index': {'SCI/TECH': 2, 'BUSINESS': 1, 'WORLD': 0, 'SPORTS': 3}, 'index2label': {0: 'WORLD', 1: 'BUSINESS', 2: 'SCI/TECH', 3: 'SPORTS'}}
# Save file at  ./report//agnews.report
#
#
#
# Description : Quick accurcy : 83.486842%
# target : agnews, instance per class : 500
#
#
#  ******************************agnews.report******************************
#               precision    recall  f1-score   support
#
#    BUSINESS       0.83      0.78      0.81      1900
#    SCI/TECH       0.81      0.78      0.80      1900
#      SPORTS       0.84      0.93      0.88      1900
#       WORLD       0.85      0.84      0.85      1900
#
# avg / total       0.83      0.83      0.83      7600
#
#  Accuracy : 0.8348684210526316
# ******************************END******************************
#
#
# 0 SPORTS {'label2index': {'SPORTS': 0}, 'index2label': {0: 'SPORTS'}}
# 1 BUSINESS {'label2index': {'SPORTS': 0, 'BUSINESS': 1}, 'index2label': {0: 'SPORTS', 1: 'BUSINESS'}}
# 2 WORLD {'label2index': {'SPORTS': 0, 'WORLD': 2, 'BUSINESS': 1}, 'index2label': {0: 'SPORTS', 1: 'BUSINESS', 2: 'WORLD'}}
# 3 SCI/TECH {'label2index': {'SCI/TECH': 3, 'SPORTS': 0, 'WORLD': 2, 'BUSINESS': 1}, 'index2label': {0: 'SPORTS', 1: 'BUSINESS', 2: 'WORLD', 3: 'SCI/TECH'}}
# Save file at  ./report//agnews.report
#
#
#
# Description : Quick accurcy : 85.289474%
# target : agnews, instance per class : 1000
#
#
#  ******************************agnews.report******************************
#               precision    recall  f1-score   support
#
#    BUSINESS       0.84      0.80      0.82      1900
#    SCI/TECH       0.83      0.81      0.82      1900
#      SPORTS       0.87      0.95      0.91      1900
#       WORLD       0.87      0.86      0.87      1900
#
# avg / total       0.85      0.85      0.85      7600
#
#  Accuracy : 0.8528947368421053
# ******************************END******************************
#
#
# 0 WORLD {'label2index': {'WORLD': 0}, 'index2label': {0: 'WORLD'}}
# 1 SPORTS {'label2index': {'SPORTS': 1, 'WORLD': 0}, 'index2label': {0: 'WORLD', 1: 'SPORTS'}}
# 2 SCI/TECH {'label2index': {'SCI/TECH': 2, 'SPORTS': 1, 'WORLD': 0}, 'index2label': {0: 'WORLD', 1: 'SPORTS', 2: 'SCI/TECH'}}
# 3 BUSINESS {'label2index': {'SCI/TECH': 2, 'SPORTS': 1, 'WORLD': 0, 'BUSINESS': 3}, 'index2label': {0: 'WORLD', 1: 'SPORTS', 2: 'SCI/TECH', 3: 'BUSINESS'}}
# Save file at  ./report//agnews.report
#
#
#
# Description : Quick accurcy : 86.197368%
# target : agnews, instance per class : 2000
#
#
#  ******************************agnews.report******************************
#               precision    recall  f1-score   support
#
#    BUSINESS       0.84      0.81      0.83      1900
#    SCI/TECH       0.85      0.82      0.83      1900
#      SPORTS       0.89      0.95      0.92      1900
#       WORLD       0.87      0.87      0.87      1900
#
# avg / total       0.86      0.86      0.86      7600
#
#  Accuracy : 0.8619736842105263
# ******************************END******************************
#
#
# 0 SPORTS {'label2index': {'SPORTS': 0}, 'index2label': {0: 'SPORTS'}}
# 1 BUSINESS {'label2index': {'SPORTS': 0, 'BUSINESS': 1}, 'index2label': {0: 'SPORTS', 1: 'BUSINESS'}}
# 2 WORLD {'label2index': {'SPORTS': 0, 'WORLD': 2, 'BUSINESS': 1}, 'index2label': {0: 'SPORTS', 1: 'BUSINESS', 2: 'WORLD'}}
# 3 SCI/TECH {'label2index': {'SCI/TECH': 3, 'SPORTS': 0, 'WORLD': 2, 'BUSINESS': 1}, 'index2label': {0: 'SPORTS', 1: 'BUSINESS', 2: 'WORLD', 3: 'SCI/TECH'}}
# Save file at  ./report//agnews.report
#
#
#
# Description : Quick accurcy : 90.368421%
# target : agnews, instance per class : total
#
#
#  ******************************agnews.report******************************
#               precision    recall  f1-score   support
#
#    BUSINESS       0.87      0.87      0.87      1900
#    SCI/TECH       0.88      0.87      0.88      1900
#      SPORTS       0.93      0.97      0.95      1900
#       WORLD       0.92      0.90      0.91      1900
#
# avg / total       0.90      0.90      0.90      7600
#
#  Accuracy : 0.9036842105263158
# ******************************END******************************
#
#
# 0 PLANT {'label2index': {'PLANT': 0}, 'index2label': {0: 'PLANT'}}
# 1 COMPANY {'label2index': {'COMPANY': 1, 'PLANT': 0}, 'index2label': {0: 'PLANT', 1: 'COMPANY'}}
# 2 OFFICEHOLDER {'label2index': {'COMPANY': 1, 'PLANT': 0, 'OFFICEHOLDER': 2}, 'index2label': {0: 'PLANT', 1: 'COMPANY', 2: 'OFFICEHOLDER'}}
# 3 MEANOFTRANSPORTATION {'label2index': {'COMPANY': 1, 'PLANT': 0, 'MEANOFTRANSPORTATION': 3, 'OFFICEHOLDER': 2}, 'index2label': {0: 'PLANT', 1: 'COMPANY', 2: 'OFFICEHOLDER', 3: 'MEANOFTRANSPORTATION'}}
# 4 EDUCATIONALINSTITUTION {'label2index': {'COMPANY': 1, 'EDUCATIONALINSTITUTION': 4, 'PLANT': 0, 'MEANOFTRANSPORTATION': 3, 'OFFICEHOLDER': 2}, 'index2label': {0: 'PLANT', 1: 'COMPANY', 2: 'OFFICEHOLDER', 3: 'MEANOFTRANSPORTATION', 4: 'EDUCATIONALINSTITUTION'}}
# 5 ARTIST {'label2index': {'COMPANY': 1, 'PLANT': 0, 'MEANOFTRANSPORTATION': 3, 'EDUCATIONALINSTITUTION': 4, 'ARTIST': 5, 'OFFICEHOLDER': 2}, 'index2label': {0: 'PLANT', 1: 'COMPANY', 2: 'OFFICEHOLDER', 3: 'MEANOFTRANSPORTATION', 4: 'EDUCATIONALINSTITUTION', 5: 'ARTIST'}}
# 6 BUILDING {'label2index': {'COMPANY': 1, 'PLANT': 0, 'MEANOFTRANSPORTATION': 3, 'EDUCATIONALINSTITUTION': 4, 'BUILDING': 6, 'ARTIST': 5, 'OFFICEHOLDER': 2}, 'index2label': {0: 'PLANT', 1: 'COMPANY', 2: 'OFFICEHOLDER', 3: 'MEANOFTRANSPORTATION', 4: 'EDUCATIONALINSTITUTION', 5: 'ARTIST', 6: 'BUILDING'}}
# 7 ANIMAL {'label2index': {'COMPANY': 1, 'PLANT': 0, 'MEANOFTRANSPORTATION': 3, 'EDUCATIONALINSTITUTION': 4, 'ANIMAL': 7, 'BUILDING': 6, 'ARTIST': 5, 'OFFICEHOLDER': 2}, 'index2label': {0: 'PLANT', 1: 'COMPANY', 2: 'OFFICEHOLDER', 3: 'MEANOFTRANSPORTATION', 4: 'EDUCATIONALINSTITUTION', 5: 'ARTIST', 6: 'BUILDING', 7: 'ANIMAL'}}
# 8 ATHLETE {'label2index': {'COMPANY': 1, 'PLANT': 0, 'MEANOFTRANSPORTATION': 3, 'EDUCATIONALINSTITUTION': 4, 'ANIMAL': 7, 'BUILDING': 6, 'ATHLETE': 8, 'ARTIST': 5, 'OFFICEHOLDER': 2}, 'index2label': {0: 'PLANT', 1: 'COMPANY', 2: 'OFFICEHOLDER', 3: 'MEANOFTRANSPORTATION', 4: 'EDUCATIONALINSTITUTION', 5: 'ARTIST', 6: 'BUILDING', 7: 'ANIMAL', 8: 'ATHLETE'}}
# 9 VILLAGE {'label2index': {'COMPANY': 1, 'PLANT': 0, 'MEANOFTRANSPORTATION': 3, 'EDUCATIONALINSTITUTION': 4, 'ANIMAL': 7, 'BUILDING': 6, 'VILLAGE': 9, 'ATHLETE': 8, 'ARTIST': 5, 'OFFICEHOLDER': 2}, 'index2label': {0: 'PLANT', 1: 'COMPANY', 2: 'OFFICEHOLDER', 3: 'MEANOFTRANSPORTATION', 4: 'EDUCATIONALINSTITUTION', 5: 'ARTIST', 6: 'BUILDING', 7: 'ANIMAL', 8: 'ATHLETE', 9: 'VILLAGE'}}
# 10 NATURALPLACE {'label2index': {'COMPANY': 1, 'NATURALPLACE': 10, 'PLANT': 0, 'MEANOFTRANSPORTATION': 3, 'EDUCATIONALINSTITUTION': 4, 'ANIMAL': 7, 'BUILDING': 6, 'VILLAGE': 9, 'ATHLETE': 8, 'ARTIST': 5, 'OFFICEHOLDER': 2}, 'index2label': {0: 'PLANT', 1: 'COMPANY', 2: 'OFFICEHOLDER', 3: 'MEANOFTRANSPORTATION', 4: 'EDUCATIONALINSTITUTION', 5: 'ARTIST', 6: 'BUILDING', 7: 'ANIMAL', 8: 'ATHLETE', 9: 'VILLAGE', 10: 'NATURALPLACE'}}
# 11 WRITTENWORK {'label2index': {'ATHLETE': 8, 'MEANOFTRANSPORTATION': 3, 'ANIMAL': 7, 'BUILDING': 6, 'VILLAGE': 9, 'WRITTENWORK': 11, 'COMPANY': 1, 'NATURALPLACE': 10, 'PLANT': 0, 'ARTIST': 5, 'EDUCATIONALINSTITUTION': 4, 'OFFICEHOLDER': 2}, 'index2label': {0: 'PLANT', 1: 'COMPANY', 2: 'OFFICEHOLDER', 3: 'MEANOFTRANSPORTATION', 4: 'EDUCATIONALINSTITUTION', 5: 'ARTIST', 6: 'BUILDING', 7: 'ANIMAL', 8: 'ATHLETE', 9: 'VILLAGE', 10: 'NATURALPLACE', 11: 'WRITTENWORK'}}
# 12 FILM {'label2index': {'ATHLETE': 8, 'MEANOFTRANSPORTATION': 3, 'ANIMAL': 7, 'BUILDING': 6, 'VILLAGE': 9, 'WRITTENWORK': 11, 'COMPANY': 1, 'NATURALPLACE': 10, 'PLANT': 0, 'ARTIST': 5, 'EDUCATIONALINSTITUTION': 4, 'FILM': 12, 'OFFICEHOLDER': 2}, 'index2label': {0: 'PLANT', 1: 'COMPANY', 2: 'OFFICEHOLDER', 3: 'MEANOFTRANSPORTATION', 4: 'EDUCATIONALINSTITUTION', 5: 'ARTIST', 6: 'BUILDING', 7: 'ANIMAL', 8: 'ATHLETE', 9: 'VILLAGE', 10: 'NATURALPLACE', 11: 'WRITTENWORK', 12: 'FILM'}}
# 13 ALBUM {'label2index': {'ATHLETE': 8, 'MEANOFTRANSPORTATION': 3, 'ANIMAL': 7, 'BUILDING': 6, 'ALBUM': 13, 'VILLAGE': 9, 'WRITTENWORK': 11, 'COMPANY': 1, 'NATURALPLACE': 10, 'PLANT': 0, 'ARTIST': 5, 'EDUCATIONALINSTITUTION': 4, 'FILM': 12, 'OFFICEHOLDER': 2}, 'index2label': {0: 'PLANT', 1: 'COMPANY', 2: 'OFFICEHOLDER', 3: 'MEANOFTRANSPORTATION', 4: 'EDUCATIONALINSTITUTION', 5: 'ARTIST', 6: 'BUILDING', 7: 'ANIMAL', 8: 'ATHLETE', 9: 'VILLAGE', 10: 'NATURALPLACE', 11: 'WRITTENWORK', 12: 'FILM', 13: 'ALBUM'}}
# Save file at  ./report//dbpedia.report
#
#
#
# Description : Quick accurcy : 77.560000%
# target : dbpedia, instance per class : 10
#
#
#  ******************************dbpedia.report******************************
#                          precision    recall  f1-score   support
#
#                  ALBUM       0.80      0.97      0.88      5000
#                 ANIMAL       0.68      0.48      0.56      5000
#                 ARTIST       0.70      0.46      0.56      5000
#                ATHLETE       0.83      0.87      0.85      5000
#               BUILDING       0.75      0.65      0.70      5000
#                COMPANY       0.71      0.62      0.66      5000
# EDUCATIONALINSTITUTION       0.81      0.89      0.85      5000
#                   FILM       0.87      0.96      0.91      5000
#   MEANOFTRANSPORTATION       0.84      0.79      0.81      5000
#           NATURALPLACE       0.81      0.82      0.82      5000
#           OFFICEHOLDER       0.72      0.81      0.76      5000
#                  PLANT       0.63      0.80      0.70      5000
#                VILLAGE       0.90      0.99      0.94      5000
#            WRITTENWORK       0.76      0.76      0.76      5000
#
#            avg / total       0.77      0.78      0.77     70000
#
#  Accuracy : 0.7756
# ******************************END******************************
#
#
# 0 ARTIST {'label2index': {'ARTIST': 0}, 'index2label': {0: 'ARTIST'}}
# 1 WRITTENWORK {'label2index': {'ARTIST': 0, 'WRITTENWORK': 1}, 'index2label': {0: 'ARTIST', 1: 'WRITTENWORK'}}
# 2 PLANT {'label2index': {'PLANT': 2, 'ARTIST': 0, 'WRITTENWORK': 1}, 'index2label': {0: 'ARTIST', 1: 'WRITTENWORK', 2: 'PLANT'}}
# 3 EDUCATIONALINSTITUTION {'label2index': {'EDUCATIONALINSTITUTION': 3, 'PLANT': 2, 'ARTIST': 0, 'WRITTENWORK': 1}, 'index2label': {0: 'ARTIST', 1: 'WRITTENWORK', 2: 'PLANT', 3: 'EDUCATIONALINSTITUTION'}}
# 4 NATURALPLACE {'label2index': {'NATURALPLACE': 4, 'EDUCATIONALINSTITUTION': 3, 'PLANT': 2, 'ARTIST': 0, 'WRITTENWORK': 1}, 'index2label': {0: 'ARTIST', 1: 'WRITTENWORK', 2: 'PLANT', 3: 'EDUCATIONALINSTITUTION', 4: 'NATURALPLACE'}}
# 5 ATHLETE {'label2index': {'ATHLETE': 5, 'NATURALPLACE': 4, 'PLANT': 2, 'EDUCATIONALINSTITUTION': 3, 'ARTIST': 0, 'WRITTENWORK': 1}, 'index2label': {0: 'ARTIST', 1: 'WRITTENWORK', 2: 'PLANT', 3: 'EDUCATIONALINSTITUTION', 4: 'NATURALPLACE', 5: 'ATHLETE'}}
# 6 BUILDING {'label2index': {'ATHLETE': 5, 'NATURALPLACE': 4, 'PLANT': 2, 'EDUCATIONALINSTITUTION': 3, 'BUILDING': 6, 'ARTIST': 0, 'WRITTENWORK': 1}, 'index2label': {0: 'ARTIST', 1: 'WRITTENWORK', 2: 'PLANT', 3: 'EDUCATIONALINSTITUTION', 4: 'NATURALPLACE', 5: 'ATHLETE', 6: 'BUILDING'}}
# 7 ALBUM {'label2index': {'ATHLETE': 5, 'NATURALPLACE': 4, 'PLANT': 2, 'EDUCATIONALINSTITUTION': 3, 'BUILDING': 6, 'ALBUM': 7, 'ARTIST': 0, 'WRITTENWORK': 1}, 'index2label': {0: 'ARTIST', 1: 'WRITTENWORK', 2: 'PLANT', 3: 'EDUCATIONALINSTITUTION', 4: 'NATURALPLACE', 5: 'ATHLETE', 6: 'BUILDING', 7: 'ALBUM'}}
# 8 ANIMAL {'label2index': {'ATHLETE': 5, 'NATURALPLACE': 4, 'PLANT': 2, 'EDUCATIONALINSTITUTION': 3, 'ANIMAL': 8, 'BUILDING': 6, 'ALBUM': 7, 'ARTIST': 0, 'WRITTENWORK': 1}, 'index2label': {0: 'ARTIST', 1: 'WRITTENWORK', 2: 'PLANT', 3: 'EDUCATIONALINSTITUTION', 4: 'NATURALPLACE', 5: 'ATHLETE', 6: 'BUILDING', 7: 'ALBUM', 8: 'ANIMAL'}}
# 9 OFFICEHOLDER {'label2index': {'ATHLETE': 5, 'NATURALPLACE': 4, 'PLANT': 2, 'EDUCATIONALINSTITUTION': 3, 'ANIMAL': 8, 'BUILDING': 6, 'OFFICEHOLDER': 9, 'ALBUM': 7, 'ARTIST': 0, 'WRITTENWORK': 1}, 'index2label': {0: 'ARTIST', 1: 'WRITTENWORK', 2: 'PLANT', 3: 'EDUCATIONALINSTITUTION', 4: 'NATURALPLACE', 5: 'ATHLETE', 6: 'BUILDING', 7: 'ALBUM', 8: 'ANIMAL', 9: 'OFFICEHOLDER'}}
# 10 COMPANY {'label2index': {'ATHLETE': 5, 'NATURALPLACE': 4, 'PLANT': 2, 'COMPANY': 10, 'EDUCATIONALINSTITUTION': 3, 'ANIMAL': 8, 'BUILDING': 6, 'OFFICEHOLDER': 9, 'ALBUM': 7, 'ARTIST': 0, 'WRITTENWORK': 1}, 'index2label': {0: 'ARTIST', 1: 'WRITTENWORK', 2: 'PLANT', 3: 'EDUCATIONALINSTITUTION', 4: 'NATURALPLACE', 5: 'ATHLETE', 6: 'BUILDING', 7: 'ALBUM', 8: 'ANIMAL', 9: 'OFFICEHOLDER', 10: 'COMPANY'}}
# 11 MEANOFTRANSPORTATION {'label2index': {'ATHLETE': 5, 'MEANOFTRANSPORTATION': 11, 'ANIMAL': 8, 'BUILDING': 6, 'ALBUM': 7, 'ARTIST': 0, 'WRITTENWORK': 1, 'COMPANY': 10, 'NATURALPLACE': 4, 'PLANT': 2, 'EDUCATIONALINSTITUTION': 3, 'OFFICEHOLDER': 9}, 'index2label': {0: 'ARTIST', 1: 'WRITTENWORK', 2: 'PLANT', 3: 'EDUCATIONALINSTITUTION', 4: 'NATURALPLACE', 5: 'ATHLETE', 6: 'BUILDING', 7: 'ALBUM', 8: 'ANIMAL', 9: 'OFFICEHOLDER', 10: 'COMPANY', 11: 'MEANOFTRANSPORTATION'}}
# 12 FILM {'label2index': {'ATHLETE': 5, 'MEANOFTRANSPORTATION': 11, 'ANIMAL': 8, 'BUILDING': 6, 'ALBUM': 7, 'ARTIST': 0, 'WRITTENWORK': 1, 'COMPANY': 10, 'NATURALPLACE': 4, 'PLANT': 2, 'EDUCATIONALINSTITUTION': 3, 'FILM': 12, 'OFFICEHOLDER': 9}, 'index2label': {0: 'ARTIST', 1: 'WRITTENWORK', 2: 'PLANT', 3: 'EDUCATIONALINSTITUTION', 4: 'NATURALPLACE', 5: 'ATHLETE', 6: 'BUILDING', 7: 'ALBUM', 8: 'ANIMAL', 9: 'OFFICEHOLDER', 10: 'COMPANY', 11: 'MEANOFTRANSPORTATION', 12: 'FILM'}}
# 13 VILLAGE {'label2index': {'ATHLETE': 5, 'MEANOFTRANSPORTATION': 11, 'ANIMAL': 8, 'BUILDING': 6, 'ALBUM': 7, 'ARTIST': 0, 'WRITTENWORK': 1, 'COMPANY': 10, 'NATURALPLACE': 4, 'PLANT': 2, 'VILLAGE': 13, 'EDUCATIONALINSTITUTION': 3, 'FILM': 12, 'OFFICEHOLDER': 9}, 'index2label': {0: 'ARTIST', 1: 'WRITTENWORK', 2: 'PLANT', 3: 'EDUCATIONALINSTITUTION', 4: 'NATURALPLACE', 5: 'ATHLETE', 6: 'BUILDING', 7: 'ALBUM', 8: 'ANIMAL', 9: 'OFFICEHOLDER', 10: 'COMPANY', 11: 'MEANOFTRANSPORTATION', 12: 'FILM', 13: 'VILLAGE'}}
# Save file at  ./report//dbpedia.report
#
#
#
# Description : Quick accurcy : 88.998571%
# target : dbpedia, instance per class : 50
#
#
#  ******************************dbpedia.report******************************
#                          precision    recall  f1-score   support
#
#                  ALBUM       0.89      0.98      0.94      5000
#                 ANIMAL       0.91      0.75      0.82      5000
#                 ARTIST       0.85      0.63      0.72      5000
#                ATHLETE       0.93      0.96      0.94      5000
#               BUILDING       0.91      0.86      0.89      5000
#                COMPANY       0.83      0.84      0.84      5000
# EDUCATIONALINSTITUTION       0.87      0.97      0.92      5000
#                   FILM       0.92      0.97      0.94      5000
#   MEANOFTRANSPORTATION       0.94      0.86      0.90      5000
#           NATURALPLACE       0.92      0.95      0.93      5000
#           OFFICEHOLDER       0.90      0.90      0.90      5000
#                  PLANT       0.81      0.91      0.86      5000
#                VILLAGE       0.97      0.99      0.98      5000
#            WRITTENWORK       0.82      0.89      0.86      5000
#
#            avg / total       0.89      0.89      0.89     70000
#
#  Accuracy : 0.8899857142857143
# ******************************END******************************
#
#
# 0 WRITTENWORK {'label2index': {'WRITTENWORK': 0}, 'index2label': {0: 'WRITTENWORK'}}
# 1 ALBUM {'label2index': {'ALBUM': 1, 'WRITTENWORK': 0}, 'index2label': {0: 'WRITTENWORK', 1: 'ALBUM'}}
# 2 MEANOFTRANSPORTATION {'label2index': {'ALBUM': 1, 'MEANOFTRANSPORTATION': 2, 'WRITTENWORK': 0}, 'index2label': {0: 'WRITTENWORK', 1: 'ALBUM', 2: 'MEANOFTRANSPORTATION'}}
# 3 BUILDING {'label2index': {'ALBUM': 1, 'BUILDING': 3, 'MEANOFTRANSPORTATION': 2, 'WRITTENWORK': 0}, 'index2label': {0: 'WRITTENWORK', 1: 'ALBUM', 2: 'MEANOFTRANSPORTATION', 3: 'BUILDING'}}
# 4 ANIMAL {'label2index': {'ANIMAL': 4, 'ALBUM': 1, 'BUILDING': 3, 'MEANOFTRANSPORTATION': 2, 'WRITTENWORK': 0}, 'index2label': {0: 'WRITTENWORK', 1: 'ALBUM', 2: 'MEANOFTRANSPORTATION', 3: 'BUILDING', 4: 'ANIMAL'}}
# 5 EDUCATIONALINSTITUTION {'label2index': {'ALBUM': 1, 'MEANOFTRANSPORTATION': 2, 'EDUCATIONALINSTITUTION': 5, 'ANIMAL': 4, 'BUILDING': 3, 'WRITTENWORK': 0}, 'index2label': {0: 'WRITTENWORK', 1: 'ALBUM', 2: 'MEANOFTRANSPORTATION', 3: 'BUILDING', 4: 'ANIMAL', 5: 'EDUCATIONALINSTITUTION'}}
# 6 FILM {'label2index': {'ALBUM': 1, 'MEANOFTRANSPORTATION': 2, 'EDUCATIONALINSTITUTION': 5, 'ANIMAL': 4, 'BUILDING': 3, 'FILM': 6, 'WRITTENWORK': 0}, 'index2label': {0: 'WRITTENWORK', 1: 'ALBUM', 2: 'MEANOFTRANSPORTATION', 3: 'BUILDING', 4: 'ANIMAL', 5: 'EDUCATIONALINSTITUTION', 6: 'FILM'}}
# 7 VILLAGE {'label2index': {'ALBUM': 1, 'MEANOFTRANSPORTATION': 2, 'EDUCATIONALINSTITUTION': 5, 'ANIMAL': 4, 'BUILDING': 3, 'FILM': 6, 'VILLAGE': 7, 'WRITTENWORK': 0}, 'index2label': {0: 'WRITTENWORK', 1: 'ALBUM', 2: 'MEANOFTRANSPORTATION', 3: 'BUILDING', 4: 'ANIMAL', 5: 'EDUCATIONALINSTITUTION', 6: 'FILM', 7: 'VILLAGE'}}
# 8 COMPANY {'label2index': {'ALBUM': 1, 'MEANOFTRANSPORTATION': 2, 'EDUCATIONALINSTITUTION': 5, 'ANIMAL': 4, 'BUILDING': 3, 'FILM': 6, 'COMPANY': 8, 'VILLAGE': 7, 'WRITTENWORK': 0}, 'index2label': {0: 'WRITTENWORK', 1: 'ALBUM', 2: 'MEANOFTRANSPORTATION', 3: 'BUILDING', 4: 'ANIMAL', 5: 'EDUCATIONALINSTITUTION', 6: 'FILM', 7: 'VILLAGE', 8: 'COMPANY'}}
# 9 ATHLETE {'label2index': {'ALBUM': 1, 'MEANOFTRANSPORTATION': 2, 'EDUCATIONALINSTITUTION': 5, 'ANIMAL': 4, 'ATHLETE': 9, 'BUILDING': 3, 'FILM': 6, 'COMPANY': 8, 'VILLAGE': 7, 'WRITTENWORK': 0}, 'index2label': {0: 'WRITTENWORK', 1: 'ALBUM', 2: 'MEANOFTRANSPORTATION', 3: 'BUILDING', 4: 'ANIMAL', 5: 'EDUCATIONALINSTITUTION', 6: 'FILM', 7: 'VILLAGE', 8: 'COMPANY', 9: 'ATHLETE'}}
# 10 ARTIST {'label2index': {'ALBUM': 1, 'MEANOFTRANSPORTATION': 2, 'EDUCATIONALINSTITUTION': 5, 'ANIMAL': 4, 'ATHLETE': 9, 'BUILDING': 3, 'FILM': 6, 'ARTIST': 10, 'COMPANY': 8, 'VILLAGE': 7, 'WRITTENWORK': 0}, 'index2label': {0: 'WRITTENWORK', 1: 'ALBUM', 2: 'MEANOFTRANSPORTATION', 3: 'BUILDING', 4: 'ANIMAL', 5: 'EDUCATIONALINSTITUTION', 6: 'FILM', 7: 'VILLAGE', 8: 'COMPANY', 9: 'ATHLETE', 10: 'ARTIST'}}
# 11 PLANT {'label2index': {'ALBUM': 1, 'MEANOFTRANSPORTATION': 2, 'ANIMAL': 4, 'BUILDING': 3, 'ATHLETE': 9, 'ARTIST': 10, 'FILM': 6, 'COMPANY': 8, 'PLANT': 11, 'VILLAGE': 7, 'EDUCATIONALINSTITUTION': 5, 'WRITTENWORK': 0}, 'index2label': {0: 'WRITTENWORK', 1: 'ALBUM', 2: 'MEANOFTRANSPORTATION', 3: 'BUILDING', 4: 'ANIMAL', 5: 'EDUCATIONALINSTITUTION', 6: 'FILM', 7: 'VILLAGE', 8: 'COMPANY', 9: 'ATHLETE', 10: 'ARTIST', 11: 'PLANT'}}
# 12 OFFICEHOLDER {'label2index': {'ALBUM': 1, 'MEANOFTRANSPORTATION': 2, 'ANIMAL': 4, 'BUILDING': 3, 'ATHLETE': 9, 'ARTIST': 10, 'FILM': 6, 'COMPANY': 8, 'PLANT': 11, 'VILLAGE': 7, 'EDUCATIONALINSTITUTION': 5, 'WRITTENWORK': 0, 'OFFICEHOLDER': 12}, 'index2label': {0: 'WRITTENWORK', 1: 'ALBUM', 2: 'MEANOFTRANSPORTATION', 3: 'BUILDING', 4: 'ANIMAL', 5: 'EDUCATIONALINSTITUTION', 6: 'FILM', 7: 'VILLAGE', 8: 'COMPANY', 9: 'ATHLETE', 10: 'ARTIST', 11: 'PLANT', 12: 'OFFICEHOLDER'}}
# 13 NATURALPLACE {'label2index': {'ALBUM': 1, 'MEANOFTRANSPORTATION': 2, 'ANIMAL': 4, 'BUILDING': 3, 'ATHLETE': 9, 'ARTIST': 10, 'FILM': 6, 'COMPANY': 8, 'NATURALPLACE': 13, 'PLANT': 11, 'VILLAGE': 7, 'EDUCATIONALINSTITUTION': 5, 'WRITTENWORK': 0, 'OFFICEHOLDER': 12}, 'index2label': {0: 'WRITTENWORK', 1: 'ALBUM', 2: 'MEANOFTRANSPORTATION', 3: 'BUILDING', 4: 'ANIMAL', 5: 'EDUCATIONALINSTITUTION', 6: 'FILM', 7: 'VILLAGE', 8: 'COMPANY', 9: 'ATHLETE', 10: 'ARTIST', 11: 'PLANT', 12: 'OFFICEHOLDER', 13: 'NATURALPLACE'}}
# Save file at  ./report//dbpedia.report
#
#
#
# Description : Quick accurcy : 90.997143%
# target : dbpedia, instance per class : 100
#
#
#  ******************************dbpedia.report******************************
#                          precision    recall  f1-score   support
#
#                  ALBUM       0.91      0.98      0.95      5000
#                 ANIMAL       0.92      0.78      0.84      5000
#                 ARTIST       0.88      0.70      0.78      5000
#                ATHLETE       0.95      0.96      0.96      5000
#               BUILDING       0.93      0.88      0.90      5000
#                COMPANY       0.87      0.86      0.86      5000
# EDUCATIONALINSTITUTION       0.90      0.96      0.93      5000
#                   FILM       0.93      0.97      0.95      5000
#   MEANOFTRANSPORTATION       0.94      0.93      0.93      5000
#           NATURALPLACE       0.93      0.98      0.95      5000
#           OFFICEHOLDER       0.93      0.92      0.93      5000
#                  PLANT       0.83      0.92      0.87      5000
#                VILLAGE       0.99      0.99      0.99      5000
#            WRITTENWORK       0.84      0.92      0.88      5000
#
#            avg / total       0.91      0.91      0.91     70000
#
#  Accuracy : 0.9099714285714285
# ******************************END******************************
#
#
# 0 ALBUM {'label2index': {'ALBUM': 0}, 'index2label': {0: 'ALBUM'}}
# 1 ANIMAL {'label2index': {'ANIMAL': 1, 'ALBUM': 0}, 'index2label': {0: 'ALBUM', 1: 'ANIMAL'}}
# 2 MEANOFTRANSPORTATION {'label2index': {'ANIMAL': 1, 'ALBUM': 0, 'MEANOFTRANSPORTATION': 2}, 'index2label': {0: 'ALBUM', 1: 'ANIMAL', 2: 'MEANOFTRANSPORTATION'}}
# 3 ATHLETE {'label2index': {'ANIMAL': 1, 'ATHLETE': 3, 'ALBUM': 0, 'MEANOFTRANSPORTATION': 2}, 'index2label': {0: 'ALBUM', 1: 'ANIMAL', 2: 'MEANOFTRANSPORTATION', 3: 'ATHLETE'}}
# 4 WRITTENWORK {'label2index': {'ANIMAL': 1, 'ATHLETE': 3, 'ALBUM': 0, 'MEANOFTRANSPORTATION': 2, 'WRITTENWORK': 4}, 'index2label': {0: 'ALBUM', 1: 'ANIMAL', 2: 'MEANOFTRANSPORTATION', 3: 'ATHLETE', 4: 'WRITTENWORK'}}
# 5 NATURALPLACE {'label2index': {'ATHLETE': 3, 'NATURALPLACE': 5, 'MEANOFTRANSPORTATION': 2, 'ANIMAL': 1, 'ALBUM': 0, 'WRITTENWORK': 4}, 'index2label': {0: 'ALBUM', 1: 'ANIMAL', 2: 'MEANOFTRANSPORTATION', 3: 'ATHLETE', 4: 'WRITTENWORK', 5: 'NATURALPLACE'}}
# 6 COMPANY {'label2index': {'ATHLETE': 3, 'NATURALPLACE': 5, 'COMPANY': 6, 'MEANOFTRANSPORTATION': 2, 'ANIMAL': 1, 'ALBUM': 0, 'WRITTENWORK': 4}, 'index2label': {0: 'ALBUM', 1: 'ANIMAL', 2: 'MEANOFTRANSPORTATION', 3: 'ATHLETE', 4: 'WRITTENWORK', 5: 'NATURALPLACE', 6: 'COMPANY'}}
# 7 BUILDING {'label2index': {'ATHLETE': 3, 'NATURALPLACE': 5, 'COMPANY': 6, 'MEANOFTRANSPORTATION': 2, 'ANIMAL': 1, 'BUILDING': 7, 'ALBUM': 0, 'WRITTENWORK': 4}, 'index2label': {0: 'ALBUM', 1: 'ANIMAL', 2: 'MEANOFTRANSPORTATION', 3: 'ATHLETE', 4: 'WRITTENWORK', 5: 'NATURALPLACE', 6: 'COMPANY', 7: 'BUILDING'}}
# 8 ARTIST {'label2index': {'ATHLETE': 3, 'NATURALPLACE': 5, 'COMPANY': 6, 'MEANOFTRANSPORTATION': 2, 'ANIMAL': 1, 'BUILDING': 7, 'ALBUM': 0, 'ARTIST': 8, 'WRITTENWORK': 4}, 'index2label': {0: 'ALBUM', 1: 'ANIMAL', 2: 'MEANOFTRANSPORTATION', 3: 'ATHLETE', 4: 'WRITTENWORK', 5: 'NATURALPLACE', 6: 'COMPANY', 7: 'BUILDING', 8: 'ARTIST'}}
# 9 EDUCATIONALINSTITUTION {'label2index': {'ATHLETE': 3, 'NATURALPLACE': 5, 'COMPANY': 6, 'MEANOFTRANSPORTATION': 2, 'EDUCATIONALINSTITUTION': 9, 'ANIMAL': 1, 'BUILDING': 7, 'ALBUM': 0, 'ARTIST': 8, 'WRITTENWORK': 4}, 'index2label': {0: 'ALBUM', 1: 'ANIMAL', 2: 'MEANOFTRANSPORTATION', 3: 'ATHLETE', 4: 'WRITTENWORK', 5: 'NATURALPLACE', 6: 'COMPANY', 7: 'BUILDING', 8: 'ARTIST', 9: 'EDUCATIONALINSTITUTION'}}
# 10 OFFICEHOLDER {'label2index': {'ATHLETE': 3, 'NATURALPLACE': 5, 'COMPANY': 6, 'MEANOFTRANSPORTATION': 2, 'EDUCATIONALINSTITUTION': 9, 'ANIMAL': 1, 'BUILDING': 7, 'OFFICEHOLDER': 10, 'ALBUM': 0, 'ARTIST': 8, 'WRITTENWORK': 4}, 'index2label': {0: 'ALBUM', 1: 'ANIMAL', 2: 'MEANOFTRANSPORTATION', 3: 'ATHLETE', 4: 'WRITTENWORK', 5: 'NATURALPLACE', 6: 'COMPANY', 7: 'BUILDING', 8: 'ARTIST', 9: 'EDUCATIONALINSTITUTION', 10: 'OFFICEHOLDER'}}
# 11 VILLAGE {'label2index': {'ATHLETE': 3, 'MEANOFTRANSPORTATION': 2, 'ANIMAL': 1, 'BUILDING': 7, 'ALBUM': 0, 'ARTIST': 8, 'WRITTENWORK': 4, 'COMPANY': 6, 'NATURALPLACE': 5, 'VILLAGE': 11, 'EDUCATIONALINSTITUTION': 9, 'OFFICEHOLDER': 10}, 'index2label': {0: 'ALBUM', 1: 'ANIMAL', 2: 'MEANOFTRANSPORTATION', 3: 'ATHLETE', 4: 'WRITTENWORK', 5: 'NATURALPLACE', 6: 'COMPANY', 7: 'BUILDING', 8: 'ARTIST', 9: 'EDUCATIONALINSTITUTION', 10: 'OFFICEHOLDER', 11: 'VILLAGE'}}
# 12 FILM {'label2index': {'ATHLETE': 3, 'MEANOFTRANSPORTATION': 2, 'ANIMAL': 1, 'BUILDING': 7, 'ALBUM': 0, 'ARTIST': 8, 'WRITTENWORK': 4, 'COMPANY': 6, 'NATURALPLACE': 5, 'VILLAGE': 11, 'EDUCATIONALINSTITUTION': 9, 'FILM': 12, 'OFFICEHOLDER': 10}, 'index2label': {0: 'ALBUM', 1: 'ANIMAL', 2: 'MEANOFTRANSPORTATION', 3: 'ATHLETE', 4: 'WRITTENWORK', 5: 'NATURALPLACE', 6: 'COMPANY', 7: 'BUILDING', 8: 'ARTIST', 9: 'EDUCATIONALINSTITUTION', 10: 'OFFICEHOLDER', 11: 'VILLAGE', 12: 'FILM'}}
# 13 PLANT {'label2index': {'ATHLETE': 3, 'MEANOFTRANSPORTATION': 2, 'ANIMAL': 1, 'BUILDING': 7, 'ALBUM': 0, 'ARTIST': 8, 'WRITTENWORK': 4, 'COMPANY': 6, 'NATURALPLACE': 5, 'PLANT': 13, 'VILLAGE': 11, 'EDUCATIONALINSTITUTION': 9, 'FILM': 12, 'OFFICEHOLDER': 10}, 'index2label': {0: 'ALBUM', 1: 'ANIMAL', 2: 'MEANOFTRANSPORTATION', 3: 'ATHLETE', 4: 'WRITTENWORK', 5: 'NATURALPLACE', 6: 'COMPANY', 7: 'BUILDING', 8: 'ARTIST', 9: 'EDUCATIONALINSTITUTION', 10: 'OFFICEHOLDER', 11: 'VILLAGE', 12: 'FILM', 13: 'PLANT'}}
# Save file at  ./report//dbpedia.report
#
#
#
# Description : Quick accurcy : 92.394286%
# target : dbpedia, instance per class : 200
#
#
#  ******************************dbpedia.report******************************
#                          precision    recall  f1-score   support
#
#                  ALBUM       0.93      0.99      0.95      5000
#                 ANIMAL       0.94      0.80      0.87      5000
#                 ARTIST       0.89      0.76      0.82      5000
#                ATHLETE       0.97      0.96      0.97      5000
#               BUILDING       0.95      0.90      0.92      5000
#                COMPANY       0.88      0.88      0.88      5000
# EDUCATIONALINSTITUTION       0.91      0.97      0.94      5000
#                   FILM       0.93      0.97      0.95      5000
#   MEANOFTRANSPORTATION       0.94      0.95      0.95      5000
#           NATURALPLACE       0.94      0.98      0.96      5000
#           OFFICEHOLDER       0.95      0.93      0.94      5000
#                  PLANT       0.85      0.93      0.89      5000
#                VILLAGE       0.99      0.98      0.99      5000
#            WRITTENWORK       0.87      0.93      0.90      5000
#
#            avg / total       0.92      0.92      0.92     70000
#
#  Accuracy : 0.9239428571428572
# ******************************END******************************
#
#
# 0 ANIMAL {'label2index': {'ANIMAL': 0}, 'index2label': {0: 'ANIMAL'}}
# 1 WRITTENWORK {'label2index': {'ANIMAL': 0, 'WRITTENWORK': 1}, 'index2label': {0: 'ANIMAL', 1: 'WRITTENWORK'}}
# 2 NATURALPLACE {'label2index': {'ANIMAL': 0, 'NATURALPLACE': 2, 'WRITTENWORK': 1}, 'index2label': {0: 'ANIMAL', 1: 'WRITTENWORK', 2: 'NATURALPLACE'}}
# 3 ARTIST {'label2index': {'ANIMAL': 0, 'NATURALPLACE': 2, 'ARTIST': 3, 'WRITTENWORK': 1}, 'index2label': {0: 'ANIMAL', 1: 'WRITTENWORK', 2: 'NATURALPLACE', 3: 'ARTIST'}}
# 4 COMPANY {'label2index': {'ANIMAL': 0, 'COMPANY': 4, 'NATURALPLACE': 2, 'ARTIST': 3, 'WRITTENWORK': 1}, 'index2label': {0: 'ANIMAL', 1: 'WRITTENWORK', 2: 'NATURALPLACE', 3: 'ARTIST', 4: 'COMPANY'}}
# 5 OFFICEHOLDER {'label2index': {'COMPANY': 4, 'NATURALPLACE': 2, 'ANIMAL': 0, 'OFFICEHOLDER': 5, 'ARTIST': 3, 'WRITTENWORK': 1}, 'index2label': {0: 'ANIMAL', 1: 'WRITTENWORK', 2: 'NATURALPLACE', 3: 'ARTIST', 4: 'COMPANY', 5: 'OFFICEHOLDER'}}
# 6 BUILDING {'label2index': {'COMPANY': 4, 'NATURALPLACE': 2, 'ANIMAL': 0, 'BUILDING': 6, 'OFFICEHOLDER': 5, 'ARTIST': 3, 'WRITTENWORK': 1}, 'index2label': {0: 'ANIMAL', 1: 'WRITTENWORK', 2: 'NATURALPLACE', 3: 'ARTIST', 4: 'COMPANY', 5: 'OFFICEHOLDER', 6: 'BUILDING'}}
# 7 ATHLETE {'label2index': {'COMPANY': 4, 'NATURALPLACE': 2, 'ANIMAL': 0, 'BUILDING': 6, 'OFFICEHOLDER': 5, 'ATHLETE': 7, 'ARTIST': 3, 'WRITTENWORK': 1}, 'index2label': {0: 'ANIMAL', 1: 'WRITTENWORK', 2: 'NATURALPLACE', 3: 'ARTIST', 4: 'COMPANY', 5: 'OFFICEHOLDER', 6: 'BUILDING', 7: 'ATHLETE'}}
# 8 MEANOFTRANSPORTATION {'label2index': {'COMPANY': 4, 'NATURALPLACE': 2, 'MEANOFTRANSPORTATION': 8, 'ANIMAL': 0, 'BUILDING': 6, 'OFFICEHOLDER': 5, 'ATHLETE': 7, 'ARTIST': 3, 'WRITTENWORK': 1}, 'index2label': {0: 'ANIMAL', 1: 'WRITTENWORK', 2: 'NATURALPLACE', 3: 'ARTIST', 4: 'COMPANY', 5: 'OFFICEHOLDER', 6: 'BUILDING', 7: 'ATHLETE', 8: 'MEANOFTRANSPORTATION'}}
# 9 FILM {'label2index': {'COMPANY': 4, 'NATURALPLACE': 2, 'MEANOFTRANSPORTATION': 8, 'ANIMAL': 0, 'BUILDING': 6, 'OFFICEHOLDER': 5, 'FILM': 9, 'ATHLETE': 7, 'ARTIST': 3, 'WRITTENWORK': 1}, 'index2label': {0: 'ANIMAL', 1: 'WRITTENWORK', 2: 'NATURALPLACE', 3: 'ARTIST', 4: 'COMPANY', 5: 'OFFICEHOLDER', 6: 'BUILDING', 7: 'ATHLETE', 8: 'MEANOFTRANSPORTATION', 9: 'FILM'}}
# 10 VILLAGE {'label2index': {'COMPANY': 4, 'NATURALPLACE': 2, 'MEANOFTRANSPORTATION': 8, 'VILLAGE': 10, 'ANIMAL': 0, 'BUILDING': 6, 'OFFICEHOLDER': 5, 'FILM': 9, 'ATHLETE': 7, 'ARTIST': 3, 'WRITTENWORK': 1}, 'index2label': {0: 'ANIMAL', 1: 'WRITTENWORK', 2: 'NATURALPLACE', 3: 'ARTIST', 4: 'COMPANY', 5: 'OFFICEHOLDER', 6: 'BUILDING', 7: 'ATHLETE', 8: 'MEANOFTRANSPORTATION', 9: 'FILM', 10: 'VILLAGE'}}
# 11 ALBUM {'label2index': {'ATHLETE': 7, 'MEANOFTRANSPORTATION': 8, 'ANIMAL': 0, 'BUILDING': 6, 'ALBUM': 11, 'VILLAGE': 10, 'FILM': 9, 'COMPANY': 4, 'NATURALPLACE': 2, 'ARTIST': 3, 'WRITTENWORK': 1, 'OFFICEHOLDER': 5}, 'index2label': {0: 'ANIMAL', 1: 'WRITTENWORK', 2: 'NATURALPLACE', 3: 'ARTIST', 4: 'COMPANY', 5: 'OFFICEHOLDER', 6: 'BUILDING', 7: 'ATHLETE', 8: 'MEANOFTRANSPORTATION', 9: 'FILM', 10: 'VILLAGE', 11: 'ALBUM'}}
# 12 PLANT {'label2index': {'ATHLETE': 7, 'MEANOFTRANSPORTATION': 8, 'ANIMAL': 0, 'BUILDING': 6, 'ALBUM': 11, 'VILLAGE': 10, 'FILM': 9, 'COMPANY': 4, 'NATURALPLACE': 2, 'PLANT': 12, 'ARTIST': 3, 'WRITTENWORK': 1, 'OFFICEHOLDER': 5}, 'index2label': {0: 'ANIMAL', 1: 'WRITTENWORK', 2: 'NATURALPLACE', 3: 'ARTIST', 4: 'COMPANY', 5: 'OFFICEHOLDER', 6: 'BUILDING', 7: 'ATHLETE', 8: 'MEANOFTRANSPORTATION', 9: 'FILM', 10: 'VILLAGE', 11: 'ALBUM', 12: 'PLANT'}}
# 13 EDUCATIONALINSTITUTION {'label2index': {'ATHLETE': 7, 'MEANOFTRANSPORTATION': 8, 'ANIMAL': 0, 'BUILDING': 6, 'ALBUM': 11, 'VILLAGE': 10, 'FILM': 9, 'COMPANY': 4, 'NATURALPLACE': 2, 'PLANT': 12, 'ARTIST': 3, 'EDUCATIONALINSTITUTION': 13, 'WRITTENWORK': 1, 'OFFICEHOLDER': 5}, 'index2label': {0: 'ANIMAL', 1: 'WRITTENWORK', 2: 'NATURALPLACE', 3: 'ARTIST', 4: 'COMPANY', 5: 'OFFICEHOLDER', 6: 'BUILDING', 7: 'ATHLETE', 8: 'MEANOFTRANSPORTATION', 9: 'FILM', 10: 'VILLAGE', 11: 'ALBUM', 12: 'PLANT', 13: 'EDUCATIONALINSTITUTION'}}
# Save file at  ./report//dbpedia.report
#
#
#
# Description : Quick accurcy : 93.950000%
# target : dbpedia, instance per class : 500
#
#
#  ******************************dbpedia.report******************************
#                          precision    recall  f1-score   support
#
#                  ALBUM       0.94      0.98      0.96      5000
#                 ANIMAL       0.96      0.87      0.91      5000
#                 ARTIST       0.90      0.81      0.85      5000
#                ATHLETE       0.97      0.97      0.97      5000
#               BUILDING       0.96      0.91      0.94      5000
#                COMPANY       0.88      0.91      0.89      5000
# EDUCATIONALINSTITUTION       0.93      0.97      0.95      5000
#                   FILM       0.94      0.97      0.96      5000
#   MEANOFTRANSPORTATION       0.95      0.96      0.96      5000
#           NATURALPLACE       0.95      0.98      0.97      5000
#           OFFICEHOLDER       0.97      0.94      0.95      5000
#                  PLANT       0.91      0.95      0.93      5000
#                VILLAGE       1.00      0.98      0.99      5000
#            WRITTENWORK       0.90      0.93      0.91      5000
#
#            avg / total       0.94      0.94      0.94     70000
#
#  Accuracy : 0.9395
# ******************************END******************************
#
#
# 0 ATHLETE {'label2index': {'ATHLETE': 0}, 'index2label': {0: 'ATHLETE'}}
# 1 MEANOFTRANSPORTATION {'label2index': {'ATHLETE': 0, 'MEANOFTRANSPORTATION': 1}, 'index2label': {0: 'ATHLETE', 1: 'MEANOFTRANSPORTATION'}}
# 2 ARTIST {'label2index': {'ATHLETE': 0, 'MEANOFTRANSPORTATION': 1, 'ARTIST': 2}, 'index2label': {0: 'ATHLETE', 1: 'MEANOFTRANSPORTATION', 2: 'ARTIST'}}
# 3 OFFICEHOLDER {'label2index': {'ATHLETE': 0, 'MEANOFTRANSPORTATION': 1, 'ARTIST': 2, 'OFFICEHOLDER': 3}, 'index2label': {0: 'ATHLETE', 1: 'MEANOFTRANSPORTATION', 2: 'ARTIST', 3: 'OFFICEHOLDER'}}
# 4 BUILDING {'label2index': {'ATHLETE': 0, 'BUILDING': 4, 'MEANOFTRANSPORTATION': 1, 'ARTIST': 2, 'OFFICEHOLDER': 3}, 'index2label': {0: 'ATHLETE', 1: 'MEANOFTRANSPORTATION', 2: 'ARTIST', 3: 'OFFICEHOLDER', 4: 'BUILDING'}}
# 5 NATURALPLACE {'label2index': {'ATHLETE': 0, 'NATURALPLACE': 5, 'MEANOFTRANSPORTATION': 1, 'BUILDING': 4, 'ARTIST': 2, 'OFFICEHOLDER': 3}, 'index2label': {0: 'ATHLETE', 1: 'MEANOFTRANSPORTATION', 2: 'ARTIST', 3: 'OFFICEHOLDER', 4: 'BUILDING', 5: 'NATURALPLACE'}}
# 6 ALBUM {'label2index': {'ATHLETE': 0, 'NATURALPLACE': 5, 'MEANOFTRANSPORTATION': 1, 'BUILDING': 4, 'ALBUM': 6, 'ARTIST': 2, 'OFFICEHOLDER': 3}, 'index2label': {0: 'ATHLETE', 1: 'MEANOFTRANSPORTATION', 2: 'ARTIST', 3: 'OFFICEHOLDER', 4: 'BUILDING', 5: 'NATURALPLACE', 6: 'ALBUM'}}
# 7 VILLAGE {'label2index': {'ATHLETE': 0, 'NATURALPLACE': 5, 'MEANOFTRANSPORTATION': 1, 'BUILDING': 4, 'VILLAGE': 7, 'ALBUM': 6, 'ARTIST': 2, 'OFFICEHOLDER': 3}, 'index2label': {0: 'ATHLETE', 1: 'MEANOFTRANSPORTATION', 2: 'ARTIST', 3: 'OFFICEHOLDER', 4: 'BUILDING', 5: 'NATURALPLACE', 6: 'ALBUM', 7: 'VILLAGE'}}
# 8 EDUCATIONALINSTITUTION {'label2index': {'ATHLETE': 0, 'NATURALPLACE': 5, 'MEANOFTRANSPORTATION': 1, 'EDUCATIONALINSTITUTION': 8, 'BUILDING': 4, 'VILLAGE': 7, 'ALBUM': 6, 'ARTIST': 2, 'OFFICEHOLDER': 3}, 'index2label': {0: 'ATHLETE', 1: 'MEANOFTRANSPORTATION', 2: 'ARTIST', 3: 'OFFICEHOLDER', 4: 'BUILDING', 5: 'NATURALPLACE', 6: 'ALBUM', 7: 'VILLAGE', 8: 'EDUCATIONALINSTITUTION'}}
# 9 COMPANY {'label2index': {'ATHLETE': 0, 'NATURALPLACE': 5, 'COMPANY': 9, 'MEANOFTRANSPORTATION': 1, 'EDUCATIONALINSTITUTION': 8, 'BUILDING': 4, 'VILLAGE': 7, 'ALBUM': 6, 'ARTIST': 2, 'OFFICEHOLDER': 3}, 'index2label': {0: 'ATHLETE', 1: 'MEANOFTRANSPORTATION', 2: 'ARTIST', 3: 'OFFICEHOLDER', 4: 'BUILDING', 5: 'NATURALPLACE', 6: 'ALBUM', 7: 'VILLAGE', 8: 'EDUCATIONALINSTITUTION', 9: 'COMPANY'}}
# 10 PLANT {'label2index': {'ATHLETE': 0, 'NATURALPLACE': 5, 'COMPANY': 9, 'MEANOFTRANSPORTATION': 1, 'EDUCATIONALINSTITUTION': 8, 'PLANT': 10, 'BUILDING': 4, 'VILLAGE': 7, 'ALBUM': 6, 'ARTIST': 2, 'OFFICEHOLDER': 3}, 'index2label': {0: 'ATHLETE', 1: 'MEANOFTRANSPORTATION', 2: 'ARTIST', 3: 'OFFICEHOLDER', 4: 'BUILDING', 5: 'NATURALPLACE', 6: 'ALBUM', 7: 'VILLAGE', 8: 'EDUCATIONALINSTITUTION', 9: 'COMPANY', 10: 'PLANT'}}
# 11 WRITTENWORK {'label2index': {'ATHLETE': 0, 'MEANOFTRANSPORTATION': 1, 'BUILDING': 4, 'ALBUM': 6, 'VILLAGE': 7, 'WRITTENWORK': 11, 'COMPANY': 9, 'NATURALPLACE': 5, 'PLANT': 10, 'ARTIST': 2, 'EDUCATIONALINSTITUTION': 8, 'OFFICEHOLDER': 3}, 'index2label': {0: 'ATHLETE', 1: 'MEANOFTRANSPORTATION', 2: 'ARTIST', 3: 'OFFICEHOLDER', 4: 'BUILDING', 5: 'NATURALPLACE', 6: 'ALBUM', 7: 'VILLAGE', 8: 'EDUCATIONALINSTITUTION', 9: 'COMPANY', 10: 'PLANT', 11: 'WRITTENWORK'}}
# 12 ANIMAL {'label2index': {'ATHLETE': 0, 'MEANOFTRANSPORTATION': 1, 'ANIMAL': 12, 'BUILDING': 4, 'ALBUM': 6, 'VILLAGE': 7, 'WRITTENWORK': 11, 'COMPANY': 9, 'NATURALPLACE': 5, 'PLANT': 10, 'ARTIST': 2, 'EDUCATIONALINSTITUTION': 8, 'OFFICEHOLDER': 3}, 'index2label': {0: 'ATHLETE', 1: 'MEANOFTRANSPORTATION', 2: 'ARTIST', 3: 'OFFICEHOLDER', 4: 'BUILDING', 5: 'NATURALPLACE', 6: 'ALBUM', 7: 'VILLAGE', 8: 'EDUCATIONALINSTITUTION', 9: 'COMPANY', 10: 'PLANT', 11: 'WRITTENWORK', 12: 'ANIMAL'}}
# 13 FILM {'label2index': {'ATHLETE': 0, 'MEANOFTRANSPORTATION': 1, 'ANIMAL': 12, 'BUILDING': 4, 'ALBUM': 6, 'VILLAGE': 7, 'WRITTENWORK': 11, 'COMPANY': 9, 'NATURALPLACE': 5, 'PLANT': 10, 'ARTIST': 2, 'EDUCATIONALINSTITUTION': 8, 'FILM': 13, 'OFFICEHOLDER': 3}, 'index2label': {0: 'ATHLETE', 1: 'MEANOFTRANSPORTATION', 2: 'ARTIST', 3: 'OFFICEHOLDER', 4: 'BUILDING', 5: 'NATURALPLACE', 6: 'ALBUM', 7: 'VILLAGE', 8: 'EDUCATIONALINSTITUTION', 9: 'COMPANY', 10: 'PLANT', 11: 'WRITTENWORK', 12: 'ANIMAL', 13: 'FILM'}}
# Save file at  ./report//dbpedia.report
#
#
#
# Description : Quick accurcy : 94.925714%
# target : dbpedia, instance per class : 1000
#
#
#  ******************************dbpedia.report******************************
#                          precision    recall  f1-score   support
#
#                  ALBUM       0.95      0.98      0.97      5000
#                 ANIMAL       0.96      0.91      0.94      5000
#                 ARTIST       0.90      0.85      0.87      5000
#                ATHLETE       0.98      0.97      0.98      5000
#               BUILDING       0.96      0.93      0.95      5000
#                COMPANY       0.91      0.91      0.91      5000
# EDUCATIONALINSTITUTION       0.94      0.97      0.96      5000
#                   FILM       0.95      0.97      0.96      5000
#   MEANOFTRANSPORTATION       0.96      0.97      0.96      5000
#           NATURALPLACE       0.96      0.99      0.97      5000
#           OFFICEHOLDER       0.97      0.94      0.96      5000
#                  PLANT       0.94      0.96      0.95      5000
#                VILLAGE       1.00      0.98      0.99      5000
#            WRITTENWORK       0.91      0.94      0.92      5000
#
#            avg / total       0.95      0.95      0.95     70000
#
#  Accuracy : 0.9492571428571429
# ******************************END******************************
#
#
# 0 BUILDING {'label2index': {'BUILDING': 0}, 'index2label': {0: 'BUILDING'}}
# 1 MEANOFTRANSPORTATION {'label2index': {'BUILDING': 0, 'MEANOFTRANSPORTATION': 1}, 'index2label': {0: 'BUILDING', 1: 'MEANOFTRANSPORTATION'}}
# 2 ALBUM {'label2index': {'BUILDING': 0, 'MEANOFTRANSPORTATION': 1, 'ALBUM': 2}, 'index2label': {0: 'BUILDING', 1: 'MEANOFTRANSPORTATION', 2: 'ALBUM'}}
# 3 ARTIST {'label2index': {'BUILDING': 0, 'MEANOFTRANSPORTATION': 1, 'ARTIST': 3, 'ALBUM': 2}, 'index2label': {0: 'BUILDING', 1: 'MEANOFTRANSPORTATION', 2: 'ALBUM', 3: 'ARTIST'}}
# 4 FILM {'label2index': {'BUILDING': 0, 'FILM': 4, 'MEANOFTRANSPORTATION': 1, 'ARTIST': 3, 'ALBUM': 2}, 'index2label': {0: 'BUILDING', 1: 'MEANOFTRANSPORTATION', 2: 'ALBUM', 3: 'ARTIST', 4: 'FILM'}}
# 5 WRITTENWORK {'label2index': {'ALBUM': 2, 'MEANOFTRANSPORTATION': 1, 'BUILDING': 0, 'WRITTENWORK': 5, 'ARTIST': 3, 'FILM': 4}, 'index2label': {0: 'BUILDING', 1: 'MEANOFTRANSPORTATION', 2: 'ALBUM', 3: 'ARTIST', 4: 'FILM', 5: 'WRITTENWORK'}}
# 6 EDUCATIONALINSTITUTION {'label2index': {'ALBUM': 2, 'MEANOFTRANSPORTATION': 1, 'EDUCATIONALINSTITUTION': 6, 'BUILDING': 0, 'WRITTENWORK': 5, 'ARTIST': 3, 'FILM': 4}, 'index2label': {0: 'BUILDING', 1: 'MEANOFTRANSPORTATION', 2: 'ALBUM', 3: 'ARTIST', 4: 'FILM', 5: 'WRITTENWORK', 6: 'EDUCATIONALINSTITUTION'}}
# 7 ATHLETE {'label2index': {'ALBUM': 2, 'MEANOFTRANSPORTATION': 1, 'EDUCATIONALINSTITUTION': 6, 'BUILDING': 0, 'WRITTENWORK': 5, 'ATHLETE': 7, 'ARTIST': 3, 'FILM': 4}, 'index2label': {0: 'BUILDING', 1: 'MEANOFTRANSPORTATION', 2: 'ALBUM', 3: 'ARTIST', 4: 'FILM', 5: 'WRITTENWORK', 6: 'EDUCATIONALINSTITUTION', 7: 'ATHLETE'}}
# 8 ANIMAL {'label2index': {'ALBUM': 2, 'MEANOFTRANSPORTATION': 1, 'EDUCATIONALINSTITUTION': 6, 'ANIMAL': 8, 'BUILDING': 0, 'WRITTENWORK': 5, 'ATHLETE': 7, 'ARTIST': 3, 'FILM': 4}, 'index2label': {0: 'BUILDING', 1: 'MEANOFTRANSPORTATION', 2: 'ALBUM', 3: 'ARTIST', 4: 'FILM', 5: 'WRITTENWORK', 6: 'EDUCATIONALINSTITUTION', 7: 'ATHLETE', 8: 'ANIMAL'}}
# 9 PLANT {'label2index': {'ALBUM': 2, 'PLANT': 9, 'MEANOFTRANSPORTATION': 1, 'EDUCATIONALINSTITUTION': 6, 'ANIMAL': 8, 'BUILDING': 0, 'WRITTENWORK': 5, 'ATHLETE': 7, 'ARTIST': 3, 'FILM': 4}, 'index2label': {0: 'BUILDING', 1: 'MEANOFTRANSPORTATION', 2: 'ALBUM', 3: 'ARTIST', 4: 'FILM', 5: 'WRITTENWORK', 6: 'EDUCATIONALINSTITUTION', 7: 'ATHLETE', 8: 'ANIMAL', 9: 'PLANT'}}
# 10 OFFICEHOLDER {'label2index': {'ALBUM': 2, 'PLANT': 9, 'MEANOFTRANSPORTATION': 1, 'EDUCATIONALINSTITUTION': 6, 'ANIMAL': 8, 'OFFICEHOLDER': 10, 'BUILDING': 0, 'WRITTENWORK': 5, 'ATHLETE': 7, 'ARTIST': 3, 'FILM': 4}, 'index2label': {0: 'BUILDING', 1: 'MEANOFTRANSPORTATION', 2: 'ALBUM', 3: 'ARTIST', 4: 'FILM', 5: 'WRITTENWORK', 6: 'EDUCATIONALINSTITUTION', 7: 'ATHLETE', 8: 'ANIMAL', 9: 'PLANT', 10: 'OFFICEHOLDER'}}
# 11 NATURALPLACE {'label2index': {'ALBUM': 2, 'MEANOFTRANSPORTATION': 1, 'ANIMAL': 8, 'BUILDING': 0, 'ATHLETE': 7, 'ARTIST': 3, 'WRITTENWORK': 5, 'NATURALPLACE': 11, 'PLANT': 9, 'EDUCATIONALINSTITUTION': 6, 'FILM': 4, 'OFFICEHOLDER': 10}, 'index2label': {0: 'BUILDING', 1: 'MEANOFTRANSPORTATION', 2: 'ALBUM', 3: 'ARTIST', 4: 'FILM', 5: 'WRITTENWORK', 6: 'EDUCATIONALINSTITUTION', 7: 'ATHLETE', 8: 'ANIMAL', 9: 'PLANT', 10: 'OFFICEHOLDER', 11: 'NATURALPLACE'}}
# 12 VILLAGE {'label2index': {'ALBUM': 2, 'MEANOFTRANSPORTATION': 1, 'ANIMAL': 8, 'BUILDING': 0, 'ATHLETE': 7, 'ARTIST': 3, 'WRITTENWORK': 5, 'NATURALPLACE': 11, 'PLANT': 9, 'VILLAGE': 12, 'EDUCATIONALINSTITUTION': 6, 'FILM': 4, 'OFFICEHOLDER': 10}, 'index2label': {0: 'BUILDING', 1: 'MEANOFTRANSPORTATION', 2: 'ALBUM', 3: 'ARTIST', 4: 'FILM', 5: 'WRITTENWORK', 6: 'EDUCATIONALINSTITUTION', 7: 'ATHLETE', 8: 'ANIMAL', 9: 'PLANT', 10: 'OFFICEHOLDER', 11: 'NATURALPLACE', 12: 'VILLAGE'}}
# 13 COMPANY {'label2index': {'ALBUM': 2, 'MEANOFTRANSPORTATION': 1, 'ANIMAL': 8, 'BUILDING': 0, 'ATHLETE': 7, 'ARTIST': 3, 'WRITTENWORK': 5, 'COMPANY': 13, 'NATURALPLACE': 11, 'PLANT': 9, 'VILLAGE': 12, 'EDUCATIONALINSTITUTION': 6, 'FILM': 4, 'OFFICEHOLDER': 10}, 'index2label': {0: 'BUILDING', 1: 'MEANOFTRANSPORTATION', 2: 'ALBUM', 3: 'ARTIST', 4: 'FILM', 5: 'WRITTENWORK', 6: 'EDUCATIONALINSTITUTION', 7: 'ATHLETE', 8: 'ANIMAL', 9: 'PLANT', 10: 'OFFICEHOLDER', 11: 'NATURALPLACE', 12: 'VILLAGE', 13: 'COMPANY'}}
# Save file at  ./report//dbpedia.report
#
#
#
# Description : Quick accurcy : 95.778571%
# target : dbpedia, instance per class : 2000
#
#
#  ******************************dbpedia.report******************************
#                          precision    recall  f1-score   support
#
#                  ALBUM       0.96      0.98      0.97      5000
#                 ANIMAL       0.97      0.94      0.96      5000
#                 ARTIST       0.92      0.88      0.90      5000
#                ATHLETE       0.98      0.98      0.98      5000
#               BUILDING       0.96      0.94      0.95      5000
#                COMPANY       0.92      0.92      0.92      5000
# EDUCATIONALINSTITUTION       0.95      0.98      0.96      5000
#                   FILM       0.96      0.97      0.97      5000
#   MEANOFTRANSPORTATION       0.97      0.97      0.97      5000
#           NATURALPLACE       0.96      0.99      0.98      5000
#           OFFICEHOLDER       0.97      0.95      0.96      5000
#                  PLANT       0.96      0.96      0.96      5000
#                VILLAGE       1.00      0.99      0.99      5000
#            WRITTENWORK       0.92      0.95      0.94      5000
#
#            avg / total       0.96      0.96      0.96     70000
#
#  Accuracy : 0.9577857142857142
# ******************************END******************************
#
#
# 0 COMPANY {'label2index': {'COMPANY': 0}, 'index2label': {0: 'COMPANY'}}
# 1 NATURALPLACE {'label2index': {'COMPANY': 0, 'NATURALPLACE': 1}, 'index2label': {0: 'COMPANY', 1: 'NATURALPLACE'}}
# 2 PLANT {'label2index': {'COMPANY': 0, 'NATURALPLACE': 1, 'PLANT': 2}, 'index2label': {0: 'COMPANY', 1: 'NATURALPLACE', 2: 'PLANT'}}
# 3 ATHLETE {'label2index': {'COMPANY': 0, 'NATURALPLACE': 1, 'PLANT': 2, 'ATHLETE': 3}, 'index2label': {0: 'COMPANY', 1: 'NATURALPLACE', 2: 'PLANT', 3: 'ATHLETE'}}
# ...
# 6 SOCIETY&CULTURE {'label2index': {'SCIENCE&MATHEMATICS': 2, 'FAMILY&RELATIONSHIPS': 3, 'EDUCATION&REFERENCE': 5, 'SPORTS': 4, 'COMPUTERS&INTERNET': 0, 'HEALTH': 1, 'SOCIETY&CULTURE': 6}, 'index2label': {0: 'COMPUTERS&INTERNET', 1: 'HEALTH', 2: 'SCIENCE&MATHEMATICS', 3: 'FAMILY&RELATIONSHIPS', 4: 'SPORTS', 5: 'EDUCATION&REFERENCE', 6: 'SOCIETY&CULTURE'}}
# 7 POLITICS&GOVERNMENT {'label2index': {'SCIENCE&MATHEMATICS': 2, 'FAMILY&RELATIONSHIPS': 3, 'POLITICS&GOVERNMENT': 7, 'EDUCATION&REFERENCE': 5, 'SPORTS': 4, 'COMPUTERS&INTERNET': 0, 'HEALTH': 1, 'SOCIETY&CULTURE': 6}, 'index2label': {0: 'COMPUTERS&INTERNET', 1: 'HEALTH', 2: 'SCIENCE&MATHEMATICS', 3: 'FAMILY&RELATIONSHIPS', 4: 'SPORTS', 5: 'EDUCATION&REFERENCE', 6: 'SOCIETY&CULTURE', 7: 'POLITICS&GOVERNMENT'}}
# 8 ENTERTAINMENT&MUSIC {'label2index': {'SCIENCE&MATHEMATICS': 2, 'FAMILY&RELATIONSHIPS': 3, 'POLITICS&GOVERNMENT': 7, 'EDUCATION&REFERENCE': 5, 'SPORTS': 4, 'ENTERTAINMENT&MUSIC': 8, 'COMPUTERS&INTERNET': 0, 'HEALTH': 1, 'SOCIETY&CULTURE': 6}, 'index2label': {0: 'COMPUTERS&INTERNET', 1: 'HEALTH', 2: 'SCIENCE&MATHEMATICS', 3: 'FAMILY&RELATIONSHIPS', 4: 'SPORTS', 5: 'EDUCATION&REFERENCE', 6: 'SOCIETY&CULTURE', 7: 'POLITICS&GOVERNMENT', 8: 'ENTERTAINMENT&MUSIC'}}
# 9 BUSINESS&FINANCE {'label2index': {'SCIENCE&MATHEMATICS': 2, 'FAMILY&RELATIONSHIPS': 3, 'POLITICS&GOVERNMENT': 7, 'BUSINESS&FINANCE': 9, 'EDUCATION&REFERENCE': 5, 'SPORTS': 4, 'ENTERTAINMENT&MUSIC': 8, 'COMPUTERS&INTERNET': 0, 'HEALTH': 1, 'SOCIETY&CULTURE': 6}, 'index2label': {0: 'COMPUTERS&INTERNET', 1: 'HEALTH', 2: 'SCIENCE&MATHEMATICS', 3: 'FAMILY&RELATIONSHIPS', 4: 'SPORTS', 5: 'EDUCATION&REFERENCE', 6: 'SOCIETY&CULTURE', 7: 'POLITICS&GOVERNMENT', 8: 'ENTERTAINMENT&MUSIC', 9: 'BUSINESS&FINANCE'}}
# Save file at  ./report//yahoo_a.report
#
#
#
# Description : Quick accurcy : 63.770000%
# target : yahoo_a, instance per class : 2000
#
#
#  ******************************yahoo_a.report******************************
#                        precision    recall  f1-score   support
#
#     BUSINESS&FINANCE       0.57      0.45      0.50      6000
#   COMPUTERS&INTERNET       0.68      0.84      0.75      6000
#  EDUCATION&REFERENCE       0.53      0.42      0.46      6000
#  ENTERTAINMENT&MUSIC       0.64      0.55      0.59      6000
# FAMILY&RELATIONSHIPS       0.59      0.77      0.67      6000
#               HEALTH       0.69      0.74      0.71      6000
#  POLITICS&GOVERNMENT       0.70      0.69      0.69      6000
#  SCIENCE&MATHEMATICS       0.61      0.71      0.66      6000
#      SOCIETY&CULTURE       0.55      0.49      0.52      6000
#               SPORTS       0.81      0.72      0.76      6000
#
#          avg / total       0.64      0.64      0.63     60000
#
#  Accuracy : 0.6377
# ******************************END******************************
#
#
# 0 POLITICS&GOVERNMENT {'label2index': {'POLITICS&GOVERNMENT': 0}, 'index2label': {0: 'POLITICS&GOVERNMENT'}}
# 1 EDUCATION&REFERENCE {'label2index': {'EDUCATION&REFERENCE': 1, 'POLITICS&GOVERNMENT': 0}, 'index2label': {0: 'POLITICS&GOVERNMENT', 1: 'EDUCATION&REFERENCE'}}
# 2 COMPUTERS&INTERNET {'label2index': {'COMPUTERS&INTERNET': 2, 'EDUCATION&REFERENCE': 1, 'POLITICS&GOVERNMENT': 0}, 'index2label': {0: 'POLITICS&GOVERNMENT', 1: 'EDUCATION&REFERENCE', 2: 'COMPUTERS&INTERNET'}}
# 3 SCIENCE&MATHEMATICS {'label2index': {'COMPUTERS&INTERNET': 2, 'EDUCATION&REFERENCE': 1, 'POLITICS&GOVERNMENT': 0, 'SCIENCE&MATHEMATICS': 3}, 'index2label': {0: 'POLITICS&GOVERNMENT', 1: 'EDUCATION&REFERENCE', 2: 'COMPUTERS&INTERNET', 3: 'SCIENCE&MATHEMATICS'}}
# 4 SPORTS {'label2index': {'COMPUTERS&INTERNET': 2, 'EDUCATION&REFERENCE': 1, 'POLITICS&GOVERNMENT': 0, 'SPORTS': 4, 'SCIENCE&MATHEMATICS': 3}, 'index2label': {0: 'POLITICS&GOVERNMENT', 1: 'EDUCATION&REFERENCE', 2: 'COMPUTERS&INTERNET', 3: 'SCIENCE&MATHEMATICS', 4: 'SPORTS'}}
# 5 ENTERTAINMENT&MUSIC {'label2index': {'SCIENCE&MATHEMATICS': 3, 'POLITICS&GOVERNMENT': 0, 'SPORTS': 4, 'EDUCATION&REFERENCE': 1, 'ENTERTAINMENT&MUSIC': 5, 'COMPUTERS&INTERNET': 2}, 'index2label': {0: 'POLITICS&GOVERNMENT', 1: 'EDUCATION&REFERENCE', 2: 'COMPUTERS&INTERNET', 3: 'SCIENCE&MATHEMATICS', 4: 'SPORTS', 5: 'ENTERTAINMENT&MUSIC'}}
# 6 BUSINESS&FINANCE {'label2index': {'SCIENCE&MATHEMATICS': 3, 'BUSINESS&FINANCE': 6, 'POLITICS&GOVERNMENT': 0, 'SPORTS': 4, 'EDUCATION&REFERENCE': 1, 'ENTERTAINMENT&MUSIC': 5, 'COMPUTERS&INTERNET': 2}, 'index2label': {0: 'POLITICS&GOVERNMENT', 1: 'EDUCATION&REFERENCE', 2: 'COMPUTERS&INTERNET', 3: 'SCIENCE&MATHEMATICS', 4: 'SPORTS', 5: 'ENTERTAINMENT&MUSIC', 6: 'BUSINESS&FINANCE'}}
# 7 HEALTH {'label2index': {'SCIENCE&MATHEMATICS': 3, 'BUSINESS&FINANCE': 6, 'POLITICS&GOVERNMENT': 0, 'SPORTS': 4, 'EDUCATION&REFERENCE': 1, 'ENTERTAINMENT&MUSIC': 5, 'COMPUTERS&INTERNET': 2, 'HEALTH': 7}, 'index2label': {0: 'POLITICS&GOVERNMENT', 1: 'EDUCATION&REFERENCE', 2: 'COMPUTERS&INTERNET', 3: 'SCIENCE&MATHEMATICS', 4: 'SPORTS', 5: 'ENTERTAINMENT&MUSIC', 6: 'BUSINESS&FINANCE', 7: 'HEALTH'}}
# 8 FAMILY&RELATIONSHIPS {'label2index': {'FAMILY&RELATIONSHIPS': 8, 'SCIENCE&MATHEMATICS': 3, 'BUSINESS&FINANCE': 6, 'POLITICS&GOVERNMENT': 0, 'SPORTS': 4, 'EDUCATION&REFERENCE': 1, 'ENTERTAINMENT&MUSIC': 5, 'COMPUTERS&INTERNET': 2, 'HEALTH': 7}, 'index2label': {0: 'POLITICS&GOVERNMENT', 1: 'EDUCATION&REFERENCE', 2: 'COMPUTERS&INTERNET', 3: 'SCIENCE&MATHEMATICS', 4: 'SPORTS', 5: 'ENTERTAINMENT&MUSIC', 6: 'BUSINESS&FINANCE', 7: 'HEALTH', 8: 'FAMILY&RELATIONSHIPS'}}
# 9 SOCIETY&CULTURE {'label2index': {'FAMILY&RELATIONSHIPS': 8, 'SCIENCE&MATHEMATICS': 3, 'BUSINESS&FINANCE': 6, 'POLITICS&GOVERNMENT': 0, 'SPORTS': 4, 'EDUCATION&REFERENCE': 1, 'ENTERTAINMENT&MUSIC': 5, 'COMPUTERS&INTERNET': 2, 'HEALTH': 7, 'SOCIETY&CULTURE': 9}, 'index2label': {0: 'POLITICS&GOVERNMENT', 1: 'EDUCATION&REFERENCE', 2: 'COMPUTERS&INTERNET', 3: 'SCIENCE&MATHEMATICS', 4: 'SPORTS', 5: 'ENTERTAINMENT&MUSIC', 6: 'BUSINESS&FINANCE', 7: 'HEALTH', 8: 'FAMILY&RELATIONSHIPS', 9: 'SOCIETY&CULTURE'}}
# Save file at  ./report//yahoo_a.report
#
#
#
# Description : Quick accurcy : 71.918333%
# target : yahoo_a, instance per class : total
#
#
#  ******************************yahoo_a.report******************************
#                        precision    recall  f1-score   support
#
#     BUSINESS&FINANCE       0.64      0.51      0.56      6000
#   COMPUTERS&INTERNET       0.81      0.88      0.84      6000
#  EDUCATION&REFERENCE       0.60      0.51      0.55      6000
#  ENTERTAINMENT&MUSIC       0.70      0.71      0.70      6000
# FAMILY&RELATIONSHIPS       0.70      0.78      0.74      6000
#               HEALTH       0.75      0.81      0.78      6000
#  POLITICS&GOVERNMENT       0.75      0.78      0.77      6000
#  SCIENCE&MATHEMATICS       0.71      0.77      0.74      6000
#      SOCIETY&CULTURE       0.61      0.58      0.59      6000
#               SPORTS       0.87      0.87      0.87      6000
#
#          avg / total       0.71      0.72      0.71     60000
#
#  Accuracy : 0.7191833333333333
# ******************************END******************************
#
#
# 0 2 {'label2index': {'2': 0}, 'index2label': {0: '2'}}
# 1 4 {'label2index': {'2': 0, '4': 1}, 'index2label': {0: '2', 1: '4'}}
# 2 3 {'label2index': {'2': 0, '3': 2, '4': 1}, 'index2label': {0: '2', 1: '4', 2: '3'}}
# 3 1 {'label2index': {'2': 0, '1': 3, '3': 2, '4': 1}, 'index2label': {0: '2', 1: '4', 2: '3', 3: '1'}}
# 4 5 {'label2index': {'2': 0, '1': 3, '3': 2, '4': 1, '5': 4}, 'index2label': {0: '2', 1: '4', 2: '3', 3: '1', 4: '5'}}
# Save file at  ./report//yelp_f.report
#
#
#
# Description : Quick accurcy : 26.552000%
# target : yelp_f, instance per class : 10
#
#
#  ******************************yelp_f.report******************************
#               precision    recall  f1-score   support
#
#           1       0.41      0.36      0.39     10000
#           2       0.23      0.15      0.18     10000
#           3       0.22      0.60      0.33     10000
#           4       0.27      0.16      0.20     10000
#           5       0.34      0.05      0.09     10000
#
# avg / total       0.29      0.27      0.24     50000
#
#  Accuracy : 0.26552
# ******************************END******************************
#
#
# 0 5 {'label2index': {'5': 0}, 'index2label': {0: '5'}}
# 1 3 {'label2index': {'3': 1, '5': 0}, 'index2label': {0: '5', 1: '3'}}
# 2 2 {'label2index': {'2': 2, '3': 1, '5': 0}, 'index2label': {0: '5', 1: '3', 2: '2'}}
# 3 4 {'label2index': {'2': 2, '3': 1, '4': 3, '5': 0}, 'index2label': {0: '5', 1: '3', 2: '2', 3: '4'}}
# 4 1 {'label2index': {'2': 2, '1': 4, '3': 1, '4': 3, '5': 0}, 'index2label': {0: '5', 1: '3', 2: '2', 3: '4', 4: '1'}}
# Save file at  ./report//yelp_f.report
#
#
#
# Description : Quick accurcy : 38.578000%
# target : yelp_f, instance per class : 50
#
#
#  ******************************yelp_f.report******************************
#               precision    recall  f1-score   support
#
#           1       0.50      0.62      0.56     10000
#           2       0.31      0.20      0.25     10000
#           3       0.31      0.24      0.27     10000
#           4       0.31      0.35      0.33     10000
#           5       0.43      0.50      0.47     10000
#
# avg / total       0.37      0.39      0.37     50000
#
#  Accuracy : 0.38578
# ******************************END******************************
#
#
# 0 1 {'label2index': {'1': 0}, 'index2label': {0: '1'}}
# 1 4 {'label2index': {'4': 1, '1': 0}, 'index2label': {0: '1', 1: '4'}}
# 2 3 {'label2index': {'4': 1, '1': 0, '3': 2}, 'index2label': {0: '1', 1: '4', 2: '3'}}
# 3 5 {'label2index': {'4': 1, '1': 0, '3': 2, '5': 3}, 'index2label': {0: '1', 1: '4', 2: '3', 3: '5'}}
# 4 2 {'label2index': {'4': 1, '1': 0, '3': 2, '2': 4, '5': 3}, 'index2label': {0: '1', 1: '4', 2: '3', 3: '5', 4: '2'}}
# Save file at  ./report//yelp_f.report
#
#
#
# Description : Quick accurcy : 41.358000%
# target : yelp_f, instance per class : 100
#
#
#  ******************************yelp_f.report******************************
#               precision    recall  f1-score   support
#
#           1       0.50      0.71      0.58     10000
#           2       0.36      0.25      0.29     10000
#           3       0.31      0.22      0.26     10000
#           4       0.34      0.31      0.32     10000
#           5       0.46      0.59      0.51     10000
#
# avg / total       0.39      0.41      0.39     50000
#
#  Accuracy : 0.41358
# ******************************END******************************
#
#
# 0 4 {'label2index': {'4': 0}, 'index2label': {0: '4'}}
# 1 3 {'label2index': {'4': 0, '3': 1}, 'index2label': {0: '4', 1: '3'}}
# 2 1 {'label2index': {'4': 0, '1': 2, '3': 1}, 'index2label': {0: '4', 1: '3', 2: '1'}}
# 3 5 {'label2index': {'4': 0, '1': 2, '3': 1, '5': 3}, 'index2label': {0: '4', 1: '3', 2: '1', 3: '5'}}
# 4 2 {'label2index': {'4': 0, '1': 2, '3': 1, '2': 4, '5': 3}, 'index2label': {0: '4', 1: '3', 2: '1', 3: '5', 4: '2'}}
# Save file at  ./report//yelp_f.report
#
#
#
# Description : Quick accurcy : 43.822000%
# target : yelp_f, instance per class : 200
#
#
#  ******************************yelp_f.report******************************
#               precision    recall  f1-score   support
#
#           1       0.49      0.77      0.60     10000
#           2       0.38      0.28      0.32     10000
#           3       0.35      0.31      0.33     10000
#           4       0.38      0.30      0.33     10000
#           5       0.53      0.53      0.53     10000
#
# avg / total       0.42      0.44      0.42     50000
#
#  Accuracy : 0.43822
# ******************************END******************************
#
#
# 0 5 {'label2index': {'5': 0}, 'index2label': {0: '5'}}
# 1 3 {'label2index': {'3': 1, '5': 0}, 'index2label': {0: '5', 1: '3'}}
# 2 4 {'label2index': {'4': 2, '3': 1, '5': 0}, 'index2label': {0: '5', 1: '3', 2: '4'}}
# 3 2 {'label2index': {'4': 2, '3': 1, '2': 3, '5': 0}, 'index2label': {0: '5', 1: '3', 2: '4', 3: '2'}}
# 4 1 {'label2index': {'4': 2, '1': 4, '3': 1, '2': 3, '5': 0}, 'index2label': {0: '5', 1: '3', 2: '4', 3: '2', 4: '1'}}
# Save file at  ./report//yelp_f.report
#
#
#
# Description : Quick accurcy : 46.802000%
# target : yelp_f, instance per class : 500
#
#
#  ******************************yelp_f.report******************************
#               precision    recall  f1-score   support
#
#           1       0.49      0.81      0.61     10000
#           2       0.40      0.30      0.34     10000
#           3       0.40      0.38      0.39     10000
#           4       0.43      0.26      0.32     10000
#           5       0.56      0.59      0.58     10000
#
# avg / total       0.46      0.47      0.45     50000
#
#  Accuracy : 0.46802
# ******************************END******************************
#
#
# 0 4 {'label2index': {'4': 0}, 'index2label': {0: '4'}}
# 1 3 {'label2index': {'4': 0, '3': 1}, 'index2label': {0: '4', 1: '3'}}
# 2 5 {'label2index': {'4': 0, '3': 1, '5': 2}, 'index2label': {0: '4', 1: '3', 2: '5'}}
# 3 2 {'label2index': {'4': 0, '3': 1, '2': 3, '5': 2}, 'index2label': {0: '4', 1: '3', 2: '5', 3: '2'}}
# 4 1 {'label2index': {'4': 0, '1': 4, '3': 1, '2': 3, '5': 2}, 'index2label': {0: '4', 1: '3', 2: '5', 3: '2', 4: '1'}}
# Save file at  ./report//yelp_f.report
#
#
#
# Description : Quick accurcy : 48.682000%
# target : yelp_f, instance per class : 1000
#
#
#  ******************************yelp_f.report******************************
#               precision    recall  f1-score   support
#
#           1       0.50      0.81      0.62     10000
#           2       0.44      0.35      0.39     10000
#           3       0.43      0.36      0.39     10000
#           4       0.45      0.31      0.36     10000
#           5       0.58      0.61      0.59     10000
#
# avg / total       0.48      0.49      0.47     50000
#
#  Accuracy : 0.48682
# ******************************END******************************
#
#
# 0 3 {'label2index': {'3': 0}, 'index2label': {0: '3'}}
# 1 1 {'label2index': {'1': 1, '3': 0}, 'index2label': {0: '3', 1: '1'}}
# 2 5 {'label2index': {'1': 1, '3': 0, '5': 2}, 'index2label': {0: '3', 1: '1', 2: '5'}}
# 3 4 {'label2index': {'4': 3, '1': 1, '3': 0, '5': 2}, 'index2label': {0: '3', 1: '1', 2: '5', 3: '4'}}
# 4 2 {'label2index': {'4': 3, '1': 1, '3': 0, '2': 4, '5': 2}, 'index2label': {0: '3', 1: '1', 2: '5', 3: '4', 4: '2'}}
# Save file at  ./report//yelp_f.report
#
#
#
# Description : Quick accurcy : 51.064000%
# target : yelp_f, instance per class : 2000
#
#
#  ******************************yelp_f.report******************************
#               precision    recall  f1-score   support
#
#           1       0.56      0.78      0.65     10000
#           2       0.45      0.42      0.44     10000
#           3       0.44      0.37      0.41     10000
#           4       0.47      0.33      0.39     10000
#           5       0.58      0.64      0.61     10000
#
# avg / total       0.50      0.51      0.50     50000
#
#  Accuracy : 0.51064
# ******************************END******************************
#
#
# 0 5 {'label2index': {'5': 0}, 'index2label': {0: '5'}}
# 1 2 {'label2index': {'2': 1, '5': 0}, 'index2label': {0: '5', 1: '2'}}
# 2 4 {'label2index': {'2': 1, '4': 2, '5': 0}, 'index2label': {0: '5', 1: '2', 2: '4'}}
# 3 1 {'label2index': {'2': 1, '1': 3, '4': 2, '5': 0}, 'index2label': {0: '5', 1: '2', 2: '4', 3: '1'}}
# 4 3 {'label2index': {'2': 1, '1': 3, '3': 4, '4': 2, '5': 0}, 'index2label': {0: '5', 1: '2', 2: '4', 3: '1', 4: '3'}}
# Save file at  ./report//yelp_f.report
#
#
#
# Description : Quick accurcy : 59.348000%
# target : yelp_f, instance per class : total
#
#
#  ******************************yelp_f.report******************************
#               precision    recall  f1-score   support
#
#           1       0.69      0.77      0.73     10000
#           2       0.55      0.50      0.52     10000
#           3       0.53      0.49      0.51     10000
#           4       0.52      0.49      0.50     10000
#           5       0.66      0.72      0.69     10000
#
# avg / total       0.59      0.59      0.59     50000
#
#  Accuracy : 0.59348
# ******************************END******************************
